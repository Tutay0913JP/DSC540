# %% [markdown]
# ### Import necessary libraries including Pandas, sqllite3, matplotlib, numpy, seaborn

# %%
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 100)

# %% [markdown]
# ### I had to pick three and extract the dataset for each milestone to a file (2,3,4) and read them

# %%
df_m2_business=pd.read_csv('bus_rest_merge_m2.txt', sep='|')

# %%
df_m3_chain=pd.read_csv('df_chain_m3.txt', sep='|')

# %%
df_m4_uscities_dem=pd.read_csv('df_us_cities_dem_m4.txt', sep='|')

# %% [markdown]
# ### Create separate tables for each dataset
#
# * YELP_BUSINESS: Milestone 2 File
# * WIKI_CHAIN: Milestone 3 Website Dataset
# * US_CITIES_DEM: Milestone 4 API

# %%
def create_table (connection_obj, sql, table_name):
    connection_obj = sqlite3.connect('yelp_restaurant2.db')
    cursor_obj = connection_obj.cursor()
    cursor_obj.execute("DROP TABLE IF EXISTS "+ table_name)
    cursor_obj.execute(sql)
    print("Table is Ready {}".format(table_name))

# %%
YELP_BUSINESS = """ CREATE TABLE YELP_BUSINESS (
            business_id                varchar(250),
            bus_name                   varchar(250),
            address                    varchar(250),
            city                       varchar(250),
            state                      varchar(250),
            postal_code                varchar(250),
            latitude                  float,
            longitude                 float,
            stars                     float,
            review_count                int64,
            is_open                     int64,
            attributes                 varchar(250),
            categories                 varchar(250),
            hours                      varchar(250),
            attribute_count             int64,
            RestaurantsPriceRange2     varchar(250),
            PriceCategory              varchar(250),
            checkin_date_list          varchar(250),
            checkin_count               int64
        ); """

# %%
create_table (connection_obj, YELP_BUSINESS,"YELP_BUSINESS" )
# Out:
# Table is Ready YELP_BUSINESS

# %%
sql = """ CREATE TABLE WIKI_CHAIN (
            chain_name                   varchar(250),
            original_location            varchar(250),
            founded                      float,
            headquarters                 varchar(250),
            parent_company               varchar(250),
            us_loc_num    varchar(250),
            areas_served                 varchar(250),
            notes                        varchar(250),
            resttype                     varchar(250)
        ); """

# %%
create_table (connection_obj, sql,"WIKI_CHAIN" )
# Out:
# Table is Ready WIKI_CHAIN

# %%
sql = """ CREATE TABLE US_CITIES_DEM (
            datasetid                  varchar(250),
            recordid                   varchar(250),
            record_timestamp           varchar(250),
            male_population            varchar(250),
            city                       varchar(250),
            number_of_veterans          int64,
            median_age                float,
            race                       varchar(250),
            count                       int64,
            female_population         float,
            state_code                 varchar(250),
            foreign_born              float,
            state                      varchar(250),
            total_population            int64,
            average_household_size    float
        ); """

# %%
create_table (connection_obj, sql,"US_CITIES_DEM" )
# Out:
# Table is Ready US_CITIES_DEM

# %% [markdown]
# ### Insert milestone 2,3,4 dataset to a table

# %%
connection_obj = sqlite3.connect('yelp_restaurant2.db')
cursor_obj = connection_obj.cursor()

# %%
# Insert Dataframe into SQL Server:
for index, row in df_m2_business.iterrows():
    cursor_obj.execute("""INSERT INTO YELP_BUSINESS (
                    business_id,
                    bus_name,
                    address,
                    city,
                    state,
                    postal_code,
                    latitude,
                    longitude,
                    stars,
                    review_count,
                      is_open,attributes,
                      categories,
                      hours,
                      attribute_count
                      ,RestaurantsPriceRange2,
                      PriceCategory,
                      checkin_date_list,
                      checkin_count) values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", 
                       (row['business_id'],
                        row['name'],
                        row['address'],
                        row['city'], 
                        row['state'],
                        row['postal_code'], 
                        row['latitude'],
                        row['latitude'],
                        row['stars'],
                        row['review_count'],
                        row['is_open'],                        
                        row['attributes'],
                        row['categories'],
                        row['hours'],
                       row['attribute_count'], 
                        row['RestaurantsPriceRange2'],
                        row['PriceCategory'],
                        row['checkin_date_list'],
                        row['checkin_count']) ) 
    connection_obj.commit()

# %%
# Insert Dataframe into SQL Server:
for index, row in df_m4_uscities_dem.iterrows():
    cursor_obj.execute("""INSERT INTO US_CITIES_DEM (
                    datasetid,
                    recordid,
                    record_timestamp,
                    male_population,
                    city,
                    number_of_veterans,
                    median_age,
                    race,
                    count,
                    female_population,
                      state_code,
                      foreign_born,
                      state,
                      total_population,
                      average_household_size) values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", 
                       (row['datasetid'],
                        row['recordid'],
                        row['record_timestamp'],
                        row['male_population'], 
                        row['city'],
                        row['number_of_veterans'], 
                        row['median_age'],
                        row['race'],
                        row['count'],
                        row['female_population'],
                        row['state_code'],
                        row['foreign_born'],                        
                        row['state'],
                        row['total_population'],
                        row['average_household_size']) ) 
    connection_obj.commit()

# %%
# Insert Dataframe into SQL Server:
for index, row in df_m3_chain.iterrows():
    cursor_obj.execute("""INSERT INTO WIKI_CHAIN  (
                    chain_name ,
                    original_location,
                    founded,
                    headquarters,
                    parent_company,
                    us_loc_num,
                    areas_served,
                    notes,
                    resttype) values(?,?,?,?,?,?,?,?,?)""", 
                       (row['Name'],
                        row['Original location'],
                        row['Founded'],
                        row['Headquarters'], 
                        row['Parent company'],
                        row['Number of U.S. locations'],
                        row['Areas served'], 
                        row['Notes'],
                        row['RestType']) ) 
    connection_obj.commit()

# %% [markdown]
# ### Do validation if records where successfully insertedt

# %%
def select_count (table_name):
    connection_obj = sqlite3.connect('yelp_restaurant2.db')
    cursor_obj = connection_obj.cursor()
    rows=cursor_obj.execute("SELECT count(*) as count FROM "+ table_name)
    for count in rows:
        print("{} table Count: {} ".format (table_name,count))

# %%
select_count('YELP_BUSINESS')
# Out:
# YELP_BUSINESS table Count: (54114,)

# %%
select_count('WIKI_CHAIN')
# Out:
# WIKI_CHAIN table Count: (298,)

# %%
select_count('US_CITIES_DEM')
# Out:
# US_CITIES_DEM table Count: (5782,)

# %% [markdown]
# ##  Using SQL, join the three tables to one dataset

# %%
data =[]
with sqlite3.connect("yelp_restaurant2.db") as conn:
    cursor = conn.cursor()
    sql = """
        select * from YELP_BUSINESS a 	left join US_CITIES_DEM b on a.state =b.state_code and a.city=b.city
								left join WIKI_CHAIN c on upper(a.bus_name) = upper(c.chain_name)
    """
    rows = cursor.execute(sql)
    for row in rows:
        data.append(row)

# %%
column_names=["business_id","bus_name","address","city","state","postal_code","latitude","longitude","stars","review_count","is_open","attributes","categories","hours","attribute_count","RestaurantsPriceRange2","PriceCategory","checkin_date_list","checkin_count","datasetid","recordid","record_timestamp","male_population","city","number_of_veterans","median_age","race","count","female_population","state_code","foreign_born","state","total_population","average_household_size","chain_name","original_location","founded","headquarters","parent_company","us_loc_num","areas_served","notes","resttype"]

# %%
YELP_MERGE_DB = pd.DataFrame(data, columns=column_names)

# %%
YELP_MERGE_DB.shape
# Out:
# (322934, 43)

# %%
YELP_MERGE_DB.head()
# Out:
#               business_id            bus_name      address          city  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 1  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 2  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 3  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
# 4  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries  935 Race St  Philadelphia
#
#   state postal_code   latitude  longitude  stars  review_count  is_open  \
# 0    PA       19107  39.955505  39.955505    4.0            80        1
# 1    PA       19107  39.955505  39.955505    4.0            80        1
# 2    PA       19107  39.955505  39.955505    4.0            80        1
# 3    PA       19107  39.955505  39.955505    4.0            80        1
# 4    PA       19107  39.955505  39.955505    4.0            80        1
#
#                                                                                             attributes  \
# 0  {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False...
# 1  {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False...
# 2  {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False...
# 4  {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False...
#
#                                               categories  \
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 1  Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 2  Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
# 4  Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries
#
#                                                                                                  hours  \
# 0  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', '...
# 1  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', '...
# 2  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', '...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', '...
# 4  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', '...
#
#    attribute_count RestaurantsPriceRange2 PriceCategory  \
# 0                3                      1           Low
# 1                3                      1           Low
# 2                3                      1           Low
# 3                3                      1           Low
# 4                3                      1           Low
#
#                                                                                      checkin_date_list  \
# 0  2010-08-18 17:05:36, 2010-11-25 17:45:31, 2011-02-27 16:58:20, 2011-05-07 14:53:45, 2011-07-23 1...
# 1  2010-08-18 17:05:36, 2010-11-25 17:45:31, 2011-02-27 16:58:20, 2011-05-07 14:53:45, 2011-07-23 1...
# 2  2010-08-18 17:05:36, 2010-11-25 17:45:31, 2011-02-27 16:58:20, 2011-05-07 14:53:45, 2011-07-23 1...
# 3  2010-08-18 17:05:36, 2010-11-25 17:45:31, 2011-02-27 16:58:20, 2011-05-07 14:53:45, 2011-07-23 1...
# 4  2010-08-18 17:05:36, 2010-11-25 17:45:31, 2011-02-27 16:58:20, 2011-05-07 14:53:45, 2011-07-23 1...
#
#    checkin_count               datasetid  \
# 0            334  us-cities-demographics
# 1            334  us-cities-demographics
# 2            334  us-cities-demographics
# 3            334  us-cities-demographics
# 4            334  us-cities-demographics
#
#                                    recordid          record_timestamp  \
# 0  0c16314c6033adf94d99b1f847f8286fa256e47f  2020-12-30T13:35:36.384Z
# 1  0c16314c6033adf94d99b1f847f8286fa256e47f  2020-12-30T13:35:36.384Z
# 2  413ed05fec8b9450e35ac3010ddef17bcfbd83a6  2020-12-30T13:35:36.384Z
# 3  413ed05fec8b9450e35ac3010ddef17bcfbd83a6  2020-12-30T13:35:36.384Z
# 4  884c3e438a064881a46906789ac81f3f18328e1d  2020-12-30T13:35:36.384Z
#
#   male_population          city  number_of_veterans  median_age  \
# 0          741270  Philadelphia             61995.0        34.1
# 1          741270  Philadelphia             61995.0        34.1
# 2          741270  Philadelphia             61995.0        34.1
# 3          741270  Philadelphia             61995.0        34.1
# 4          741270  Philadelphia             61995.0        34.1
#
#                         race     count  female_population state_code  \
# 0         hispanic or latino  219038.0           826172.0         PA
# 1         hispanic or latino  219038.0           826172.0         PA
# 2                      asian  122721.0           826172.0         PA
# 3                      asian  122721.0           826172.0         PA
# 4  black or african-american  691186.0           826172.0         PA
#
#    foreign_born         state  total_population  average_household_size  \
# 0      205339.0  Pennsylvania         1567442.0                    2.61
# 1      205339.0  Pennsylvania         1567442.0                    2.61
# 2      205339.0  Pennsylvania         1567442.0                    2.61
# 3      205339.0  Pennsylvania         1567442.0                    2.61
# 4      205339.0  Pennsylvania         1567442.0                    2.61
#
#   chain_name original_location  founded headquarters parent_company  \
# 0       None              None      NaN         None           None
# 1       None              None      NaN         None           None
# 2       None              None      NaN         None           None
# 3       None              None      NaN         None           None
# 4       None              None      NaN         None           None
#
#   us_loc_num areas_served notes resttype
# 0       None         None  None     None
# 1       None         None  None     None
# 2       None         None  None     None
# 3       None         None  None     None
# 4       None         None  None     None

# %% [markdown]
# ### Create Visualization

# %%
#     // integer, 0 or 1 for closed or open, respectively

df_m2_business_open=df_m2_business[df_m2_business.is_open==1]
df_m2_business_close=df_m2_business[df_m2_business.is_open==0]

# %%
plt.hist([df_m2_business_open['stars'], df_m2_business_close['stars']], bins, label=['Open Business', 'Close Business'])
plt.legend(loc='upper right')
plt.title("Stars Rating Histogram for Open and Close Businesses")
plt.xlabel("Star Rating", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
plt.hist([df_m2_business_open['attribute_count'], df_m2_business_close['attribute_count']], bins, label=['Open Business', 'Close Business'])
plt.legend(loc='upper right')
plt.title("Attribute_count Histogram for Open and Close Businesses")
plt.xlabel("Attribute Count", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.xlim=[0, 15]
plt.ylim=[0, 4000]
plt.show()

# %%
df_m2_business['RestaurantsPriceRange2'].hist()
plt.grid(True)
plt.title("Restaurant Price range Histogram")
plt.xlabel("Restaurant Prices range", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_m2_business.plot.scatter('attribute_count', 'checkin_count', s=150, c='orange', edgecolor='k')
plt.grid(True)
plt.title(" Attribute Count v.s Checkin_count")
plt.xlabel("Attribute Count", fontsize=15)
plt.ylabel("Checkin Count", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Use Merged Dataset for Visualization

# %%
YELP_MERGE_CHAIN_OPEN.head(5)
# Out:
#                business_id                 bus_name             address  city  \
# 74  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St  Reno
# 75  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St  Reno
# 76  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St  Reno
# 77  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St  Reno
# 78  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St  Reno
#
#    state postal_code   latitude  longitude  stars  review_count  ...  \
# 74    NV       89502  39.476117  39.476117    2.5           339  ...
# 75    NV       89502  39.476117  39.476117    2.5           339  ...
# 76    NV       89502  39.476117  39.476117    2.5           339  ...
# 77    NV       89502  39.476117  39.476117    2.5           339  ...
# 78    NV       89502  39.476117  39.476117    2.5           339  ...
#
#     average_household_size               chain_name    original_location  \
# 74                    2.46  Romano's Macaroni Grill  Leon Springs, Texas
# 75                    2.46  Romano's Macaroni Grill  Leon Springs, Texas
# 76                    2.46  Romano's Macaroni Grill  Leon Springs, Texas
# 77                    2.46  Romano's Macaroni Grill  Leon Springs, Texas
# 78                    2.46  Romano's Macaroni Grill  Leon Springs, Texas
#
#    founded      headquarters parent_company us_loc_num areas_served  notes  \
# 74  1988.0  Denver, Colorado           None         40         None   None
# 75  1988.0  Denver, Colorado           None         40         None   None
# 76  1988.0  Denver, Colorado           None         40         None   None
# 77  1988.0  Denver, Colorado           None         40         None   None
# 78  1988.0  Denver, Colorado           None         40         None   None
#
#    resttype
# 74  Italian
# 75  Italian
# 76  Italian
# 77  Italian
# 78  Italian
#
# [5 rows x 43 columns]

# %%
#Created two dataframe to compare open chain and close chain restaurants

YELP_MERGE_CHAIN_OPEN=YELP_MERGE_DB[(YELP_MERGE_DB['is_open']==1 ) & ( ~YELP_MERGE_DB['chain_name'].isnull())]
YELP_MERGE_CHAIN_CLOSE=YELP_MERGE_DB[(YELP_MERGE_DB['is_open']==0 ) & ( ~YELP_MERGE_DB['chain_name'].isnull())]

# %%
plt.hist([YELP_MERGE_CHAIN_OPEN['checkin_count'], YELP_MERGE_CHAIN_CLOSE['checkin_count']], bins, label=['Open Business', 'Close Business'])
plt.legend(loc='upper right')
plt.title("Chain Checkin Count Histogram for Open and Close Businesses")
plt.xlabel("Chain Checkin Count", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
YELP_MERGE_CHAIN_OPEN.plot.scatter('attribute_count', 'checkin_count', s=150, c='orange', edgecolor='k')
plt.grid(True)
plt.title(" Attribute Count v.s Checkin_count for Open Chain Restaurants")
plt.xlabel("Attribute Count", fontsize=15)
plt.ylabel("Checkin Count", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Filter two restaurant chain and compare them: Sandwich and Sub category
YELP_MERGE_CHAIN_SUB = YELP_MERGE_DB.loc[(YELP_MERGE_DB.chain_name == 'Subway') | (YELP_MERGE_DB.chain_name == 'Jimmy John\'s')]

# %%
fig = plt.figure(figsize=(8, 6))
sns.boxplot(x = 'chain_name', y = 'stars', data = YELP_MERGE_CHAIN_SUB)
plt.title("Rating Comparison: Subway vs Jimmy John's",fontsize = 20)
plt.ylabel('Stars', fontsize = 12)
plt.xlabel('Chain Name', fontsize = 12);
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
YELP_MERGE_CHAIN_OPEN.plot.scatter('checkin_count', 'count', s=150, c='orange', edgecolor='k')
plt.grid(True)
plt.title(" checkin_count v.s City Population of Chain Restaurants")
plt.xlabel("Checkin count", fontsize=15)
plt.ylabel("City Population", fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
